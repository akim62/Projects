# %%
# import dependecies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
shootings_list_df = pd.read_csv("dataset/fatal-police-shootings-data.csv")
shootings_list_df.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# 3  Not fleeing        False
# 4  Not fleeing        False

# %%
shootings_droppedna_df = shootings_list_df.dropna(how="any")
shootings_droppedna_df.count()
# Out:
# id                         3450
# name                       3450
# date                       3450
# manner_of_death            3450
# armed                      3450
# age                        3450
# gender                     3450
# race                       3450
# city                       3450
# state                      3450
# signs_of_mental_illness    3450
# threat_level               3450
# flee                       3450
# body_camera                3450
# dtype: int64

# %%
# Attempt to change data for race and gender columns
shootings_droppedna_df["race"] = shootings_droppedna_df.race.map({'A':'Asian', 'W':'White, Non-Hispanic', 
'B':'Black, Non-Hispanic', 'N':'Native American', 'H':'Hispanic', 'O':'Other'})

shootings_droppedna_df["gender"]=shootings_droppedna_df.gender.map({'M': 'Male', 'F': 'Female'})
shootings_droppedna_df.head()
# Out:
#    id                name  date   manner_of_death       armed  age gender  \
# 0   3          Tim Elliot  2015              shot         gun   53    NaN
# 1   4    Lewis Lee Lembke  2015              shot         gun   47    NaN
# 2   5  John Paul Quintero  2015  shot and Tasered     unarmed   23    NaN
# 3   8     Matthew Hoffman  2015              shot  toy weapon   32    NaN
# 4   9   Michael Rodriguez  2015              shot    nail gun   39    NaN
#
#   race           city state  signs_of_mental_illness threat_level  \
# 0  NaN        Shelton    WA                     True       attack
# 1  NaN          Aloha    OR                    False       attack
# 2  NaN        Wichita    KS                    False        other
# 3  NaN  San Francisco    CA                     True       attack
# 4  NaN          Evans    CO                    False       attack
#
#           flee  body_camera Age Group
# 0  Not fleeing        False  50 to 54
# 1  Not fleeing        False  45 to 49
# 2  Not fleeing        False  20 to 24
# 3  Not fleeing        False  30 to 34
# 4  Not fleeing        False  35 to 39

# %%
# Changed datatype for age to int in order to be able to remove decimals
shootings_droppedna_df.loc[:, "age"] = shootings_droppedna_df["age"].astype("int")
shootings_droppedna_df.dtypes
# Out:
# /Users/aleckim/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# id                          int64
# name                       object
# date                       object
# manner_of_death            object
# armed                      object
# age                         int64
# gender                     object
# race                       object
# city                       object
# state                      object
# signs_of_mental_illness      bool
# threat_level               object
# flee                       object
# body_camera                  bool
# dtype: object

# %%
# Decimal removed from age 
shootings_droppedna_df=shootings_droppedna_df.round()
shootings_droppedna_df.head()
# Out:
#    id                name        date   manner_of_death       armed  age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun   53
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun   47
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed   23
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon   32
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun   39
#
#   gender                 race           city state  signs_of_mental_illness  \
# 0   Male                Asian        Shelton    WA                     True
# 1   Male  White, Non-Hispanic          Aloha    OR                    False
# 2   Male             Hispanic        Wichita    KS                    False
# 3   Male  White, Non-Hispanic  San Francisco    CA                     True
# 4   Male             Hispanic          Evans    CO                    False
#
#   threat_level         flee  body_camera
# 0       attack  Not fleeing        False
# 1       attack  Not fleeing        False
# 2        other  Not fleeing        False
# 3       attack  Not fleeing        False
# 4       attack  Not fleeing        False

# %%
# Splitting the date to only pull the year
shootings_droppedna_df["date"]= shootings_droppedna_df["date"].str.split("-", n = 1, expand = True)
shootings_droppedna_df.head()
# Out:
#    id                name  date   manner_of_death       armed  age gender  \
# 0   3          Tim Elliot  2015              shot         gun   53    NaN
# 1   4    Lewis Lee Lembke  2015              shot         gun   47    NaN
# 2   5  John Paul Quintero  2015  shot and Tasered     unarmed   23    NaN
# 3   8     Matthew Hoffman  2015              shot  toy weapon   32    NaN
# 4   9   Michael Rodriguez  2015              shot    nail gun   39    NaN
#
#   race           city state  signs_of_mental_illness threat_level  \
# 0  NaN        Shelton    WA                     True       attack
# 1  NaN          Aloha    OR                    False       attack
# 2  NaN        Wichita    KS                    False        other
# 3  NaN  San Francisco    CA                     True       attack
# 4  NaN          Evans    CO                    False       attack
#
#           flee  body_camera Age Group
# 0  Not fleeing        False  50 to 54
# 1  Not fleeing        False  45 to 49
# 2  Not fleeing        False  20 to 24
# 3  Not fleeing        False  30 to 34
# 4  Not fleeing        False  35 to 39

# %%
# Total number of shootings
total_count= shootings_droppedna_df["name"].count()
total_count
# Out:
# 3450

# %%
#Changed format for race and gender columns
shootings_droppedna_df["race"] = shootings_droppedna_df.race.map({'A':'Asian', 'W':'White, Non-Hispanic', 
'B':'Black, Non-Hispanic', 'N':'Native American', 'H':'Hispanic', 'O':'Other'})

shootings_droppedna_df["gender"]=shootings_droppedna_df.gender.map({'M': 'Male', 'F': 'Female'})
shootings_droppedna_df

#split the date to pull only year
shootings_droppedna_df["date"]= shootings_droppedna_df["date"].str.split("-", n = 1, expand = True)
shootings_droppedna_df

#rename date to year
renamed_shootings_table=shootings_droppedna_df.rename(columns={"date": "year", "armed": "Type of Weapon"})
renamed_shootings_table

#changed datatype for age to int in order to be able to remove decimals
renamed_shootings_table.loc[:, "age"] = renamed_shootings_table["age"].astype("int")
renamed_shootings_table.dtypes

#decimal removed from age 
renamed_shootings_table=renamed_shootings_table.round()
renamed_shootings_table.head()
# Out:
#    id                name  year   manner_of_death Type of Weapon  age gender  \
# 0   3          Tim Elliot  2015              shot            gun   53    NaN
# 1   4    Lewis Lee Lembke  2015              shot            gun   47    NaN
# 2   5  John Paul Quintero  2015  shot and Tasered        unarmed   23    NaN
# 3   8     Matthew Hoffman  2015              shot     toy weapon   32    NaN
# 4   9   Michael Rodriguez  2015              shot       nail gun   39    NaN
#
#   race           city state  signs_of_mental_illness threat_level  \
# 0  NaN        Shelton    WA                     True       attack
# 1  NaN          Aloha    OR                    False       attack
# 2  NaN        Wichita    KS                    False        other
# 3  NaN  San Francisco    CA                     True       attack
# 4  NaN          Evans    CO                    False       attack
#
#           flee  body_camera Age Group
# 0  Not fleeing        False  50 to 54
# 1  Not fleeing        False  45 to 49
# 2  Not fleeing        False  20 to 24
# 3  Not fleeing        False  30 to 34
# 4  Not fleeing        False  35 to 39

# %%
#number of shootings per year
year_groups = renamed_shootings_table["year"].value_counts()
year_groups.head()

#creating dataframe and resetting index
year_groups_df=pd.DataFrame(year_groups)
year_groups_df=year_groups_df.reset_index()

#renaming columns
year_groups_df=year_groups_df.rename(columns={"index": "Year", "year": "Count by Year"})
year_groups_df
# Out:
#    Year  Count by Year
# 0  2015            895
# 1  2016            814
# 2  2017            783
# 3  2018            780
# 4  2019            178

# %%
year_trend = plt.bar(year_groups_df["Year"], year_groups_df["Count by Year"], color='blue', label="Year", align="center")
plt.xlabel("Year")
plt.ylabel("Number of shootings")
plt.title("Year over Year trend")
plt.text(5, 50, 'Incomplete 2019 data', style='italic',
         bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})
year_trend
# Out:
# <BarContainer object of 5 artists>

# %%
# Number of shootings by gender
gender_groups = shootings_droppedna_df["gender"].value_counts()
gender_groups.head()
# Out:
# Male      3294
# Female     156
# Name: gender, dtype: int64

# %%
# Percentage of shootings by gender
gender_percentage = (gender_groups/total_count).map("{:.2%}".format)
gender_percentage
# Out:
# Male      95.48%
# Female     4.52%
# Name: gender, dtype: object

# %%
# Number of shootings by gender summary dataframe
gender_summary_df=pd.DataFrame({
    "Gender Total":gender_groups,
    "Gender Percentage":gender_percentage
})
gender_summary_df
# Out:
#         Gender Total Gender Percentage
# Male            3294            95.48%
# Female           156             4.52%

# %%
# Number of shootings by race
race_groups = shootings_droppedna_df["race"].value_counts()
race_groups.head()
# Out:
# White, Non-Hispanic    1783
# Black, Non-Hispanic     885
# Hispanic                626
# Asian                    64
# Native American          58
# Name: race, dtype: int64

# %%
# Percentage of shootings by race
race_percentage = (race_groups/total_count).map("{:.2%}".format)
race_percentage
# Out:
# White, Non-Hispanic    51.68%
# Black, Non-Hispanic    25.65%
# Hispanic               18.14%
# Asian                   1.86%
# Native American         1.68%
# Other                   0.99%
# Name: race, dtype: object

# %%
# Shootings by race pie chart
labels = ["White", "Black", "Hispanic", "Asian", "Native American", "Other"]
colors = ["yellow", "purple", "orange", "green", "lightcoral", "blue"]
explode = (0, 0, 0, 0, 0, 0)
plt.pie(race_groups, explode=explode, labels=labels, colors=colors, autopct="%1.1f%%", shadow=True, startangle=140)
plt.title("Percentage of shootings by race")
plt.axis("tight")
# Out:
# (-1.1097669881654402,
#  1.1083024373052925,
#  -1.1092736520078934,
#  1.1039723517096596)

# %%
# Shootings by race bar chart
plt.bar(labels, race_groups, alpha=0.25, color="r")
plt.tight_layout()

# %%
race_summary_df=pd.DataFrame({
    "Race Total":race_groups,
    "Race Percentage":race_percentage
})
race_summary_df
# Out:
#                      Race Total Race Percentage
# White, Non-Hispanic        1783          51.68%
# Black, Non-Hispanic         885          25.65%
# Hispanic                    626          18.14%
# Asian                        64           1.86%
# Native American              58           1.68%
# Other                        34           0.99%

# %%
# Number of shootings by state
shootings_by_state = shootings_droppedna_df.groupby(["state"]).count()["name"]
shootings_by_state.head(25)
# Out:
# state
# AK     22
# AL     66
# AR     46
# AZ    169
# CA    505
# CO    109
# CT     11
# DC     12
# DE      8
# FL    219
# GA    111
# HI     17
# IA     24
# ID     27
# IL     78
# IN     67
# KS     37
# KY     61
# LA     72
# MA     24
# MD     43
# ME     12
# MI     58
# MN     47
# MO     86
# Name: name, dtype: int64

# %%
# Pulling columns from main dataframe
state_race_table = shootings_droppedna_df [["name","date", "state", "race"]]
state_race_table.head(10)
# Out:
#                   name  date state                 race
# 0           Tim Elliot  2015    WA                Asian
# 1     Lewis Lee Lembke  2015    OR  White, Non-Hispanic
# 2   John Paul Quintero  2015    KS             Hispanic
# 3      Matthew Hoffman  2015    CA  White, Non-Hispanic
# 4    Michael Rodriguez  2015    CO             Hispanic
# 5    Kenneth Joe Brown  2015    OK  White, Non-Hispanic
# 6  Kenneth Arnold Buck  2015    AZ             Hispanic
# 7        Brock Nichols  2015    KS  White, Non-Hispanic
# 8        Autumn Steele  2015    IA  White, Non-Hispanic
# 9      Leslie Sapp III  2015    PA  Black, Non-Hispanic

# %%
# Count by year, state and race
count_state_race = state_race_table.groupby(["date", "state", "race"]).count()["name"]
count_state_race.head(25)
# Out:
# date  state  race
# 2015  AK     Native American         2
#              White, Non-Hispanic     2
#       AL     Black, Non-Hispanic     6
#              White, Non-Hispanic    11
#       AR     Black, Non-Hispanic     1
#              White, Non-Hispanic     3
#       AZ     Hispanic               12
#              Native American         1
#              White, Non-Hispanic    26
#       CA     Asian                   7
#              Black, Non-Hispanic    31
#              Hispanic               70
#              Other                   7
#              White, Non-Hispanic    50
#       CO     Asian                   1
#              Black, Non-Hispanic     5
#              Hispanic                7
#              Native American         1
#              White, Non-Hispanic    11
#       CT     White, Non-Hispanic     2
#       DC     Black, Non-Hispanic     4
#       DE     Black, Non-Hispanic     1
#              White, Non-Hispanic     1
#       FL     Black, Non-Hispanic    23
#              Hispanic                9
# Name: name, dtype: int64

# %%
# Age group classification
# Getting max and min in order to determine age bin limits
print(shootings_droppedna_df["age"].max())
print(shootings_droppedna_df["age"].min())
# Out:
# 91
# 6

# %%
bins = [4, 9, 14, 19, 24, 29, 34, 39, 44, 49, 54, 59, 64, 69, 74, 79, 84, 89, 94]

group_labels= ["5 to 9", "10 to 14", "15 to 19", "20 to 24", "25 to 29", "30 to 34", "35 to 39", "40 to 44", "45 to 49",
              "50 to 54", "55 to 59", "60 to 64", "65 to 69", "70 to 74", "75 to 79", "80 to 84", "85 to 89", "90 to 94"]

# adding Age Group column and pulling in age by bins and labels
shootings_droppedna_df["Age Group"] = pd.cut(shootings_droppedna_df["age"], bins, labels=group_labels)

# grouping by Age Group in order to be able to perform count function
group_by_age = shootings_droppedna_df.groupby("Age Group")
agegroup_count = group_by_age["Age Group"].count()

# %%
# Age group bar chart
plt.bar(group_labels, agegroup_count, alpha=0.5, color="r")
plt.xticks(rotation=90)
plt.tight_layout()

# %%
# Number of people who attacked and did not flee
threat_and_flee = shootings_droppedna_df.loc[(shootings_droppedna_df["threat_level"] == "attack") 
                                             & (shootings_droppedna_df["flee"] == "Not fleeing") 
                                             & (shootings_droppedna_df["signs_of_mental_illness"] == True)]
age_group = threat_and_flee.groupby("Age Group").count()

# clean dataframe
age_group = age_group[["signs_of_mental_illness", "threat_level", "flee"]]
renamed_age_group = age_group.rename(columns={
    "signs_of_mental_illness": "Signs of Mental Illness (T)",
    "threat_level": "Attack",
    "flee": "Not Fleeing"
})
renamed_age_group

# bar chart
# Out:
#            Signs of Mental Illness (T)  Attack  Not Fleeing
# Age Group
# 5 to 9                               0       0            0
# 10 to 14                             0       0            0
# 15 to 19                            11      11           11
# 20 to 24                            35      35           35
# 25 to 29                            61      61           61
# 30 to 34                            73      73           73
# 35 to 39                            56      56           56
# 40 to 44                            36      36           36
# 45 to 49                            33      33           33
# 50 to 54                            45      45           45
# 55 to 59                            45      45           45
# 60 to 64                            22      22           22
# 65 to 69                            14      14           14
# 70 to 74                             6       6            6
# 75 to 79                             3       3            3
# 80 to 84                             2       2            2
# 85 to 89                             0       0            0
# 90 to 94                             0       0            0

# %%
# Pulling columns from main dataframe
state_age_table = shootings_droppedna_df [["name","date", "Age Group"]]
state_age_table.head(10)
# Out:
#                   name  date Age Group
# 0           Tim Elliot  2015  50 to 54
# 1     Lewis Lee Lembke  2015  45 to 49
# 2   John Paul Quintero  2015  20 to 24
# 3      Matthew Hoffman  2015  30 to 34
# 4    Michael Rodriguez  2015  35 to 39
# 5    Kenneth Joe Brown  2015  15 to 19
# 6  Kenneth Arnold Buck  2015  20 to 24
# 7        Brock Nichols  2015  35 to 39
# 8        Autumn Steele  2015  30 to 34
# 9      Leslie Sapp III  2015  45 to 49

# %%
count_state_age = state_age_table.groupby(["date", "Age Group"]).count()["name"]
count_state_age.head(25)
# Out:
# date  Age Group
# 2015  5 to 9         1.0
#       10 to 14       NaN
#       15 to 19      47.0
#       20 to 24     119.0
#       25 to 29     152.0
#       30 to 34     134.0
#       35 to 39     119.0
#       40 to 44      77.0
#       45 to 49      94.0
#       50 to 54      61.0
#       55 to 59      46.0
#       60 to 64      25.0
#       65 to 69      11.0
#       70 to 74       4.0
#       75 to 79       4.0
#       80 to 84       1.0
#       85 to 89       NaN
#       90 to 94       NaN
# 2016  5 to 9         NaN
#       10 to 14       3.0
#       15 to 19      46.0
#       20 to 24      98.0
#       25 to 29     129.0
#       30 to 34     137.0
#       35 to 39     126.0
# Name: name, dtype: float64

# %%
#Number of shootings by state
shootings_by_state = shootings_droppedna_df.groupby(["state"]).count()["name"]
shootings_by_state

#creating dataframe and resetting index
for_top_states_df = pd.DataFrame(shootings_by_state)               
for_top_states_df=for_top_states_df.reset_index()
for_top_states_df

#renaming column
for_top_states_df=for_top_states_df.rename(columns={"state": "State", "name": "Count by State"})
for_top_states_df

# sorted state count
sorted_top_states= for_top_states_df.sort_values("Count by State", ascending=False)
sorted_top_states.head(5)
# Out:
#    State  Count by State
# 4     CA             505
# 43    TX             286
# 9     FL             219
# 3     AZ             169
# 35    OH             111

# %%
sorted_top_states.plot(kind="bar", x="State", y="Count by State", figsize=(20, 3))
plt.title("Number of shootings per State")
plt.tight_layout()

# %%
# Shot by state 
manner_group = pd.DataFrame(shootings_droppedna_df.groupby(['manner_of_death','state']).size())
shot = pd.DataFrame(manner_group.loc['shot',0]).reset_index()
states_list = shot['state']
st = pd.DataFrame(manner_group.loc['shot and Tasered',0]).reset_index()
st = st.rename(columns = {0: 'Shot & Tasered'})
shot = shot.rename(columns = {0: 'Shot'})
shot.head()
# Out:
#   state  Shot
# 0    AK    22
# 1    AL    62
# 2    AR    46
# 3    AZ   161
# 4    CA   463

# %%
# Shot and tasered by state
combined = shot.merge(st, on='state')
combined.set_index('state', inplace=True)
combined.head()
# Out:
#        Shot  Shot & Tasered
# state
# AL       62               4
# AZ      161               8
# CA      463              42
# CO      107               2
# CT        9               2

# %%
# Stacked bar chart 
multi_plot = combined.plot(kind="bar", figsize=(20,5), stacked=True)

plt.show()
plt.tight_layout()

# %%
percentages = (combined.sum())/3131
percentages
# Out:
# Shot              0.939317
# Shot & Tasered    0.060683
# dtype: float64

# %%
# Plotting percentages of shot and shot & tasered
plot = percentages.plot.pie(y='Shot', figsize=(5, 5))

# %%
# List of weapons used by victims
race_unarmed = shootings_droppedna_df[['race', 'armed']]
race_unarmed.armed.unique()
# Out:
# array(['gun', 'unarmed', 'toy weapon', 'nail gun', 'knife', 'shovel',
#        'hammer', 'hatchet', 'undetermined', 'sword', 'machete',
#        'box cutter', 'metal object', 'screwdriver', 'lawn mower blade',
#        'flagpole', 'guns and explosives', 'cordless drill', 'metal pole',
#        'Taser', 'metal pipe', 'metal hand tool', 'blunt object',
#        'metal stick', 'sharp object', 'meat cleaver', 'carjack', 'chain',
#        "contractor's level", 'unknown weapon', 'stapler', 'crossbow',
#        'bean-bag gun', 'baseball bat and fireplace poker',
#        'straight edge razor', 'gun and knife', 'ax', 'brick',
#        'baseball bat', 'hand torch', 'chain saw', 'garden tool',
#        'scissors', 'pole', 'pick-axe', 'flashlight', 'spear', 'chair',
#        'pitchfork', 'hatchet and gun', 'rock', 'piece of wood', 'bayonet',
#        'glass shard', 'motorcycle', 'pepper spray', 'metal rake', 'baton',
#        'crowbar', 'oar', 'machete and gun', 'air conditioner',
#        'pole and knife', 'beer bottle', 'pipe', 'baseball bat and bottle',
#        'fireworks', 'pen', 'chainsaw', 'gun and sword', 'gun and car',
#        'vehicle', 'pellet gun', 'BB gun', 'incendiary device',
#        'samurai sword', 'bow and arrow', 'gun and vehicle',
#        'vehicle and gun', 'wrench'], dtype=object)
